# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import matplotlib.pyplot as plt
import numpy as np

# %%
(train_data, train_labels), (test_data, test_labels) = tf.keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 4s 0us/step

# %%
plt.figure()
plt.imshow(train_data[0])
plt.colorbar()
plt.grid = False
plt.show()

# %%
train_data = np.reshape(train_data, (60000, 28*28))
test_data = np.reshape(test_data, (10000, 28*28))

train_data = train_data / 255.0
test_data = test_data / 255.0

# %%
train_data.shape
# Out:
# (60000, 784)

# %%
model = Sequential([
                    Dense(32, activation='relu', input_shape=(784,)),
                    Dense(32, activation='relu'),
                    Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(train_data, train_labels, epochs=5, validation_split=0.2)
# Out:
# Epoch 1/5
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.3812 - accuracy: 0.8913 - val_loss: 0.2120 - val_accuracy: 0.9384
# Epoch 2/5
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1883 - accuracy: 0.9453 - val_loss: 0.1917 - val_accuracy: 0.9450
# Epoch 3/5
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1520 - accuracy: 0.9545 - val_loss: 0.1572 - val_accuracy: 0.9526
# Epoch 4/5
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1288 - accuracy: 0.9610 - val_loss: 0.1375 - val_accuracy: 0.9609
# Epoch 5/5
# 1500/1500 [==============================] - 1s 973us/step - loss: 0.1113 - accuracy: 0.9669 - val_loss: 0.1467 - val_accuracy: 0.9581

# %%
model.save("NNV/model.h5")
